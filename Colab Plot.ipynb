# %%
import os
import matplotlib.pyplot as plt
#plt.style.use("ggplot")

import pandas as pd

# %%
path = '/content/quant.sf'

# %%
df = pd.read_table(path)

# %%
df.head()
# Out:
#    Name  Length  EffectiveLength  TPM  NumReads
# 0     1      48             48.0  0.0       0.0
# 1     2      48             48.0  0.0       0.0
# 2     3      48             48.0  0.0       0.0
# 3     4      48             48.0  0.0       0.0
# 4     5      48             48.0  0.0       0.0

# %%
counts = sorted(list(df['NumReads']), reverse=True)

# %%
plt.bar(range(len(counts[:20000])), counts[:20000], color='black', width=50)
plt.title('N70 Barcode')
plt.ylabel('Reads')
plt.xticks([])
plt.ylim(0, 2500)
#plt.xlim(0, 1000000)
#plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))

plt.savefig('N70_barcode.png')
